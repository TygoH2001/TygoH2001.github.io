# %% [markdown]
# Assignment 1

# %%
import pandas as pd
#Change the path to the downloaded file
xlsx = 'C:/Users/tygoh/Downloads/2020_jaarboek_941_4eccf4d8b6.xlsx'
df = pd.read_excel(xlsx)

#from txt to NaN, so it is all numeric
df['totaal fosfor'] = pd.to_numeric(df['totaal fosfor'], errors='coerce')

column1 = 'totaal fosfor'

min_value = df[column1].min()
max_value = df[column1].max()

print(f"Minimum value in {column1} : {min_value}")
print(f"Maximum value in {column1} : {max_value}")
# Out:
# Minimum value in totaal fosfor : 0.02
# Maximum value in totaal fosfor : 2.03

# %% [markdown]
# Assignment 2

# %%
# How much is 33% of the 7350 registered vessels?
      
number_boats = 7350
percentage_electric = 33
electric_boats = (percentage_electric / 100) * number_boats
      
print(electric_boats)
# Out:
# 2425.5

# %%
#550 boats out of 7350 are commercial vessels - percentage?

number_commercial = 550

percentage_commercial = (100/number_boats) * number_commercial

print(percentage_commercial)
# Out:
# 7.482993197278911

# %%
#amout of necessary lifeboats and supportboats
average_amount = 1/500
lenght = 5000
start_boat = 1
communication = 2
buffer = 1

amount_boats = lenght * average_amount + start_boat + communication + buffer
print(amount_boats)
# Out:
# 14.0

# %%
#Energy for electric boat motors (amount_boats is extracted from last code snippet)
             
kWh = 15.5
hours_per_day = 2
days = 7
            
energy_use = kWh * hours_per_day * days * amount_boats
enery_price = energy_use * 0.12
      
print(energy_use)
print(enery_price)
# Out:
# 3038.0
# 364.56

# %% [markdown]
# Assignment 3

# %%
# Assignment 3.1
# What will Amsterdam receive from tourist tax?
# The event lasts a week with 30.000 visitors

import pandas as pd

# Airbnb tax
Airbnb_visitors = 30000 * 0.12 # 12% stays at Airbnb
Airbnb_appartments = Airbnb_visitors / 3 # based on average occupation of 3

bnb_data = pd.read_csv('listings.csv') 
bnb_price = bnb_data['price'].mean()
print("The mean price of Airbnbs in Amsterdam is:", bnb_price)

Airbnb_tax = (bnb_price * Airbnb_appartments) * 0.1
Airbnb_tax_week = Airbnb_tax * 7
print(Airbnb_tax_week)

# Hotel direct tax
direct_tax = 25000 * 3
direct_tax_week = direct_tax * 7
print(direct_tax_week)

# Hotel indirect tax
average_price = 189 # average hotel price september 2023
hotel_rooms = 12500 # based on average occupation of 2
indirect_tax = (average_price * hotel_rooms) * 0.07
indirect_tax_week = indirect_tax * 7
print(indirect_tax_week)

# Total tourist tax
total_tax = Airbnb_tax_week + direct_tax_week + indirect_tax_week
print(total_tax, "euro")
# Out:
# The mean price of Airbnbs in Amsterdam is: 254.48986405914619
# 213771.4858096828
# 525000
# 1157625.0000000002
# 1896396.485809683 euro

# %%
# Assignment 3.2

import pandas as pd
import plotly.express as px

# Plot the amount of AirBnB locations per neighborhood
bnb_data = pd.read_csv('listings.csv')

neighbourhood = bnb_data['neighbourhood'].value_counts().reset_index()
neighbourhood.columns = ['neighbourhood', 'count']
print(neighbourhood)

fig = px.bar(neighbourhood, x='neighbourhood', y='count', title='number of AirBnB locations per neighbourhood in Amsterdam')
fig.update_xaxes(title='neighbourhood')
fig.update_yaxes(title='number of AirBnBs') 
fig.show()
# Out:
#                              neighbourhood  count
# 0                   De Baarsjes - Oud-West   1382
# 1                             Centrum-West   1006
# 2                  De Pijp - Rivierenbuurt    935
# 3                             Centrum-Oost    793
# 4                                     Zuid    599
# 5                               Westerpark    584
# 6                                 Oud-Oost    506
# 7                            Bos en Lommer    424
# 8                                Oud-Noord    402
# 9   Oostelijk Havengebied - Indische Buurt    320
# 10                         Watergraafsmeer    262
# 11                              Noord-West    218
# 12                IJburg - Zeeburgereiland    183
# 13                             Slotervaart    164
# 14                              Noord-Oost    137
# 15                 Geuzenveld - Slotermeer    116
# 16                  Buitenveldert - Zuidas    100
# 17                  De Aker - Nieuw Sloten     74
# 18                   Gaasperdam - Driemond     51
# 19                         Bijlmer-Centrum     47
# 20                                  Osdorp     44
# 21                            Bijlmer-Oost     39

# %%
# Assignment 3.3
# Which street in Amsterdam has the most AirBnB apartments?
# Takes almost an hour to run
from geopy.geocoders import Nominatim
import pandas as pd
import os.path

bnb_data = pd.read_csv('listings.csv')
location = bnb_data.groupby(['latitude', 'longitude']).size().reset_index(name='count') 

geolocator = Nominatim(user_agent="airbnb_geocoder") 
def get_street_from_location(lat, lon):
    try: 
        location_info = geolocator.reverse((lat,lon), exactly_one=True) 
        return location_info.address
    except: 
        return "N/A"

location['street'] = location.apply(lambda row: get_street_from_location(row['latitude'], row['longitude']), axis=1) 

most_popular_location = location.sort_values(by='count', ascending=False).iloc[0]
print("The street with the most Airbnb listings in Amsterdam is:", most_popular_location['street']) 
print("Number of Airbnb listings in this street:", most_popular_location['count'])

# %%
# Assignment 3.4
# Which number of apartments are not rented out all the time?

import pandas as pd
import matplotlib.pyplot as plt

threshold = 365
availability = bnb_data['availability_365']<365
housing = availability.shape[0]
print("Number of apartments used as normal housing:", housing)

gem_availability = bnb_data['availability_365'].mean()
print("Gemiddelde beschikbaarheid per jaar:", gem_availability)

bnb_data.hist(column='availability_365') 
plt.title("Availability Airbnbs Amsterdam") 
plt.xlabel("Availability in Days") 
plt.ylabel("Number of Apartments") 
plt.show()
# Out:
# Number of apartments used as normal housing: 8386
# Gemiddelde beschikbaarheid per jaar: 82.82506558549964

# %%
# Assignment 3.5
# How many hotel rooms should be built to accommodate Airbnb tourists

bnb_df = pd.read_csv('listings.csv') 
split_name = bnb_df['name'].str.split('·', expand=True)
split_name.columns = ['Property', 'Rating', 'Bedrooms', 'Beds', 'Baths']
bnb_df = pd.concat([bnb_df, split_name], axis=1)
print(bnb_df)

print(bnb_df['Beds'])
bnb_df['Beds'] = bnb_df['Beds'].str.extract('([\d.]+)').astype(float)
print(bnb_df['Beds'])

total_beds = int(bnb_df['Beds'].sum())
print("Totaal aantal bedden:", total_beds)
# Out:
#                       id                                               name  \
# 0                 761411  Condo in Amsterdam · ★4.74 · 1 bedroom · 1 bed...
# 1                 768274  Rental unit in Amsterdam · ★4.83 · 1 bedroom ·...
# 2                 768737  Boat in Amsterdam · ★4.82 · 1 bedroom · 1 bed ...
# 3                 771217  Houseboat in Amsterdam · ★5.0 · 3 bedrooms · 3...
# 4                 771343  Rental unit in Amsterdam · ★4.89 · 1 bedroom ·...
# ...                  ...                                                ...
# 8381  971403658453358540  Rental unit in Amsterdam · ★New · 1 bedroom · ...
# 8382  971600466535392582  Home in Amsterdam · ★New · 3 bedrooms · 3 beds...
# 8383  971686543447319533  Rental unit in Amsterdam · ★New · 1 bedroom · ...
# 8384  971758168481363169  Hotel in Amsterdam · ★New · 1 bedroom · 1 bed ...
# 8385  972218247170836285  Condo in Amsterdam · ★New · 2 bedrooms · 1 bed...
#
#         host_id host_name  neighbourhood_group            neighbourhood  \
# 0       4013546    Xsjong                  NaN               Noord-Oost
# 1       3678216     J & R                  NaN               Westerpark
# 2       3877342    Nicole                  NaN               Westerpark
# 3       4068486  Danielle                  NaN                     Zuid
# 4       2313061    Marcel                  NaN             Centrum-West
# ...         ...       ...                  ...                      ...
# 8381    6879236   Michiel                  NaN                Oud-Noord
# 8382  307559908     Chris                  NaN                Oud-Noord
# 8383  170194324      Yara                  NaN            Bos en Lommer
# 8384   55794534     David                  NaN             Centrum-West
# 8385    2876582     Doris                  NaN  De Pijp - Rivierenbuurt
#
#        latitude  longitude        room_type  price  ...  reviews_per_month  \
# 0     52.401640   4.951060     Private room     61  ...               2.30
# 1     52.388550   4.885210  Entire home/apt    327  ...               0.64
# 2     52.378240   4.868260     Private room    109  ...               2.73
# 3     52.340910   4.848020  Entire home/apt    290  ...               0.11
# 4     52.376410   4.883030     Private room    150  ...               6.62
# ...         ...        ...              ...    ...  ...                ...
# 8381  52.394972   4.906180  Entire home/apt    250  ...                NaN
# 8382  52.387880   4.911080  Entire home/apt    337  ...                NaN
# 8383  52.386497   4.848041  Entire home/apt    135  ...                NaN
# 8384  52.372431   4.894491     Private room    160  ...                NaN
# 8385  52.342122   4.909411  Entire home/apt    211  ...                NaN
#
#       calculated_host_listings_count availability_365  number_of_reviews_ltm  \
# 0                                  2              272                     26
# 1                                  1               16                      6
# 2                                  3               29                     43
# 3                                  1                0                      0
# 4                                  2              196                    110
# ...                              ...              ...                    ...
# 8381                               1                9                      0
# 8382                               1              267                      0
# 8383                               1               13                      0
# 8384                               1                6                      0
# 8385                               1               55                      0
#
#                        license                   Property   Rating  \
# 0     0363 D4AD DCF3 E72A 56A2        Condo in Amsterdam    ★4.74
# 1     0363 7A50 18E7 51D1 B7F9  Rental unit in Amsterdam    ★4.83
# 2         036396BE30827DDB9575         Boat in Amsterdam    ★4.82
# 3     0363 D807 AD6C 499A F871    Houseboat in Amsterdam     ★5.0
# 4     0363 8C61 E9B9 5582 913E  Rental unit in Amsterdam    ★4.89
# ...                        ...                        ...      ...
# 8381  0363 9080 FE38 A7CE E7B7  Rental unit in Amsterdam     ★New
# 8382  0363 5639 0AD2 7A88 3FED         Home in Amsterdam     ★New
# 8383  0363 C287 34D9 EA25 9428  Rental unit in Amsterdam     ★New
# 8384                    Exempt        Hotel in Amsterdam     ★New
# 8385  0363 2F20 4F53 FB57 2D7F        Condo in Amsterdam     ★New
#
#           Bedrooms      Beds            Baths
# 0       1 bedroom     1 bed     1 shared bath
# 1       1 bedroom     1 bed           2 baths
# 2       1 bedroom     1 bed         1.5 baths
# 3      3 bedrooms    3 beds         2.5 baths
# 4       1 bedroom     1 bed    1 private bath
# ...            ...       ...              ...
# 8381    1 bedroom     1 bed            1 bath
# 8382   3 bedrooms    3 beds            1 bath
# 8383    1 bedroom     1 bed         1.5 baths
# 8384    1 bedroom     1 bed     1 shared bath
# 8385   2 bedrooms     1 bed            1 bath
#
# [8386 rows x 23 columns]
# 0         1 bed
# 1         1 bed
# 2         1 bed
# 3        3 beds
# 4         1 bed
#           ...
# 8381      1 bed
# 8382     3 beds
# 8383      1 bed
# 8384      1 bed
# 8385      1 bed
# Name: Beds, Length: 8386, dtype: object
# 0       1.0
# 1       1.0
# 2       1.0
# 3       3.0
# 4       1.0
#        ...
# 8381    1.0
# 8382    3.0
# 8383    1.0
# 8384    1.0
# 8385    1.0
# Name: Beds, Length: 8386, dtype: float64
# Totaal aantal bedden: 14713

# %%
# Assignment 3.6
# How many different licenses are issued?

licenses = bnb_data['license'].nunique()
print("Number of different licenses issued:", licenses)
print(len(bnb_data))

license_count = bnb_data['license'].value_counts()
mostissued = license_count.max()
print("The most issued license holder has", mostissued)
# Out:
# Number of different licenses issued: 7288
# 8386
# The most issued license holder has 609

# %% [markdown]
# Assignment 4

# %%
# Assignment 4.1
import geopandas as gpd

# Read the file made on the internet
line_data = gpd.read_file('C:/Users/tygoh/Downloads/map.geojson')

# Calculate the middle of the line and coordinates
midpoint = line_data.geometry.interpolate(0.5, normalized=True)

print(midpoint)
# Out:
# 0    POINT (4.89871 52.36383)
# dtype: geometry
# C:\Users\tygoh\AppData\Local\Temp\ipykernel_9436\2361481299.py:7: UserWarning:
#
# Geometry is in a geographic CRS. Results from 'interpolate' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.

# %%
# Assignment 4.2
amount_of_people = 32 * 175
print(amount_of_people)
# Out:
# 5600

# %%
amount_of_people = 20 * 150
print(amount_of_people)
# Out:
# 3000

# %%
# Assignment 4.3
# Cafes, Bars and Restaurant around the fnish line

# we need the requests library to get the data from OSM and the folium library to plot the map

import requests
import folium

# We define the query to search for cafes, bars and restaurants with Overpass API

overpass_url = "https://overpass-api.de/api/interpreter"

# we define the radius in meter and the coordinates of Van Mierlobrug (end point of the swimming route) 

overpass_query = """
[out:json];
(
  node(around:850, 52.37683, 4.88984); 
  way(around:850, 52.37683, 4.88984);
  rel(around:850, 52.37683, 4.88984);
);
out center;
"""

# We send the query to the Overpass API to get the data

response = requests.get(overpass_url, params={"data": overpass_query})

if response.status_code == 200:
    data = response.json()

    # We set 0 as the start value for counting
    cafe_count = 0
    bar_count = 0
    restaurant_count = 0

    # We open 3 lists to store the cafe, bar and restaurant names
    cafe_names = []
    bar_names = []
    restaurant_names = []
   # We create a map of the coordinates to plot the results and markers for the map

    m = folium.Map(location=[52.37683, 4.88984], zoom_start=15)

    cafe_markers = folium.FeatureGroup(name='Cafes')

    restaurant_markers = folium.FeatureGroup(name='Restaurants')

    bar_markers = folium.FeatureGroup (name='bar')

    # We iterate through the elements, count all cafes, bars, and restaurants, add the to the map and add their names to the 3 lists
    
    for element in data['elements']:
        if 'tags' in element:
            tags = element['tags']
            if 'name' in tags:
                name = tags['name']
                if 'amenity' in tags:
                    amenity = tags['amenity']
                    if amenity == 'cafe':
                        cafe_count += 1
                        cafe_names.append(name)
                        location = (element.get('lat'), element.get('lon'))
                        popup = tags.get('name', 'Cafe')
                        icon_color = 'blue'
                        if None not in location:
                            cafe_markers.add_child(folium.Marker(
                            location=location,
                            popup=popup,
                            icon=folium.Icon(color=icon_color)
                            ))
                    elif amenity == 'bar':
                        bar_count += 1
                        bar_names.append(name)
                        location = (element.get('lat'), element.get('lon'))
                        popup = tags.get('name', 'Bar')
                        icon_color = 'green'
                        if None not in location:
                            bar_markers.add_child(folium.Marker(
                            location=location,
                            popup=popup,
                            icon=folium.Icon(color=icon_color)
                            ))
                    elif amenity == 'restaurant':
                        restaurant_count += 1
                        restaurant_names.append(name)
                        location = (element.get('lat'), element.get('lon'))
                        popup = tags.get('name', 'Restaurant')
                        icon_color = 'orange'
                        if None not in location:
                            restaurant_markers.add_child(folium.Marker(
                            location=location,
                            popup=popup,
                            icon=folium.Icon(color=icon_color)
                            ))


    # we print the numbers of cafes, bars, and restaurants in the 850m radius

    print(f"Number of cafes: {cafe_count}")

    print(f"Number of bars: {bar_count}")

    print(f"Number of restaurants: {restaurant_count}")

    # we want to have a list of all names of those cafes, bars and restaurants (remove if you don`t want too much information)

    print("Cafes:")
    for name in cafe_names:
        print(name)
    
    print("\nBars:")
    for name in bar_names:
        print(name)

    print("\nRestaurants:")
    for name in restaurant_names:
        print(name)

    # we add the markers to the map
    m.add_child(cafe_markers)
    m.add_child(bar_markers)
    m.add_child(restaurant_markers)

    # we add a layer control for themarkers
    folium.LayerControl().add_to(m)

    # we plot the map in Jupyter Lab
m
# Out:
# Number of cafes: 137
# Number of bars: 70
# Number of restaurants: 357
# Cafes:
# Stock
# Coffeeshop Rock-it
# Moods coffee corner
# Corner House Hotel Cafe
# Cafe de Barones
# De Kletskop
# De Ooievaar
# Kobalt
# Arrive
# Cafe Nobo
# Van Gogh Cafe
# Drupa Coffee Roasters
# Coffee Company
# Coffee Company
# Bagels & Beans
# Starbucks
# Tom's bread & more
# Coffee Company
# Small World Catering
# 't Nieuwe Kafé
# Broodbar
# Cafe Het Paleis
# De Hoek
# Bistro Berlage
# Café Tabac
# De Drie Graefjes
# G's
# Mekhong River
# De Blaffende Vis
# Het Monumentje
# SLA
# The Cold Pressed Juicery
# Café Wester
# Coffeeshop Relax
# Property of
# Cocotte
# Greenwoods
# Green Planet Coffeeshop
# Caffe Il Momento
# Lost in amsterdam
# L'Amour
# Resin Coffeeshop
# Mediterrané coffeeshop
# Barney's Coffeeshop
# The Bulldog Rock Shop
# Vinnies
# Dam Good Coffee
# Melly’s Stroopwafels
# Starbucks
# Bagels Sandwich Village
# Pluk
# Libertine
# Scheltema
# Diep
# New Times coffeeshop
# Le Pain Quotidien
# Kadinsky Coffeeshop
# ‘t Doktertje
# Eat Mode
# Oriental City
# Wagamama
# Grekas Greek Deli
# Little Saigon
# Dolce Vita
# Mexican Restaurant
# Guadalupe
# Steakhouse
# Woodstone&Fire
# 5&33
# Shiki
# Allstars
# At James
# Pasta Pizza Crėpes Panini
# Koh-i-Noor
# Barbecue
# Burger Zaken
# La Cuisine Ronde
# Siga La Vaca
# Mas y Mas
# Mas y Mas
# TerraZen Centre
# The Taste of Vietnam
# Pacifico
# Lucca
# Het Karbeel
# San Tommaso
# El Asador
# Rio Bueno
# China Si Chuan Restaurant
# Aneka Rasa
# Seafood Bistro
# Caffe Italia
# Restaurant 40
# Wok Inn
# Da Giorgio
# Pita Palace
# Caffe Italia
# Kam Wah
# Grizzly
# The Duchess
# Caldi e Freddi
# Meneer pannenkoek
# Mr Porter
# CAU
# Terpentijn
# Pancakes Amsterdam
# Casa del Toro
# Pancakes
# Hummus Bistro D&A
# Lucius
# The Good Companion
# Ava Cyril
# Wolf Atelier
# Café de Paris
# Bird
# Lucca Due
# Royal98
# Burgerij
# Black and Blue
# Humphrey's
# Hoogendam
# Koh-I-Noor
# Spanjer en van Twist
# San Thomas
# Amsterdam
# Ramen-Ya
# Cannibale Royale
# Hong Kong Kitchen
# Fabian
# The Old Church
# Kooning van Siam
# Paleis van de Weemoed
# American Bar-bq
# Mekhong River
# Saint Morris
# De Nissen
# Bistro-Brasserie Blue
# Thai Fusion
# Bistro Bij Ons
# Dabka
# Brasserie Ambassade
# Cannibale Royale
# DOS
# Green House Munchies
# Il Panorama
# Toos & Roos
# Melkmeisje
# De Kroonprins
# Si-Chuan
# Taste of Culture
# Santa Vergine
# La Casa Argentina
# Destra del Ponte
# Samrai
# Oude Wester
# Tanoshii sushi
# La Zoccola del Pacioccone
# Formosa Argentina
# Casa del Toro
# La Casa
# Mr. Crab
# St. Paul’s
# da filippo
# Luciën’s
# Tropico
# The Lobby
# Pizza Pasta Steaks
# Jacketz
# Bougainville
# Lokaal Loosie
# Nacarat
# The White Room by Jacob Jan Boerma
# The White Room by Jacob Jan Boerma
# Max indosian
# Lotti’s Dinner
# Bussia
# Restaurant van Puffelen
# Madam Pancake
# Sunlight Lounge
# Argentalia
# Madre
# Sins of Sal
# Ramen-Kingdom
# Ellis Gourmet Burger
# Domenica
# Van 't Spit
# ta toru
# O Bistro
# Swieti Sranang
# Luna
# Adam Palace
# Salmuera
# SLA
# Café Carbòn
# Mr Meat Steakhouse Amsterdam
# Il Pacioccone
# Pho Viet
# Burgerbar
# Kinnaree
# La Maschera
# Galette
# Capri
# Balraj
# La Brasa
# Ko Chang
# Café de Parel
# Jottum
# Sonkran
# Afhaalcentrum Terang Boelan
# Ristorante Pepe
# Il Fiore
# Pequ
# Chok Dee
# Swieti sranang
# Winkel 43
# Mr Haz
# Ponte Vecchio
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_632dd1c8046b0a8bcb0f95d6fd83eb47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_632dd1c8046b0a8bcb0f95d6fd83eb47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_632dd1c8046b0a8bcb0f95d6fd83eb47 = L.map(
#                 &quot;map_632dd1c8046b0a8bcb0f95d6fd83eb47&quot;,
#                 {
#                     center: [52.37683, 4.88984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41b04b3d608c904f3ab66368ef580d4b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_632dd1c8046b0a8bcb0f95d6fd83eb47);
#
#
#             var feature_group_f307b2a623dd54b0757be207f6de160a = L.featureGroup(
#                 {}
#             ).addTo(map_632dd1c8046b0a8bcb0f95d6fd83eb47);
#
#
#             var marker_961fdeee5a2ec2fa0bb5d64be46e545a = L.marker(
#                 [52.3753858, 4.8956474],
#                 {}
#             ).addTo(feature_group_f307b2a623dd54b0757be207f6de160a);
#
#
#             var icon_7a9e26cf52d59e4540a43685e4712a4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_961fdeee5a2ec2fa0bb5d64be46e545a.setIcon(icon_7a9e26cf52d59e4540a43685e4712a4f);
#
#
#         var popup_4d58eed51b96f20de328b354bc90c21a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7e4a11b3631ea0291cb40e5659435d5 = $(`&lt;div id=&quot;html_f7e4a11b3631ea0291cb40e5659435d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stock&lt;/div&gt;`)[0];
#                 popup_4d58eed51b96f20de328b354bc90c21a.setContent(html_f7e4a11b3631ea0291cb40e5659435d5);
#
#
#
#         marker_961fdeee5a2ec2fa0bb5d64be46e545a.bindPopup(popup_4d58eed51b96f20de328b354bc90c21a)
#         ;
#
#
#
#
#             var marker_67be5b3f50695792a70daa316f00c8eb = L.marker(
#                 [52.3728646, 4.8998649],
#                 {}
#             ).addTo(feature_group_f307b2a623dd54b0757be207f6de160a);
#
#
#             var icon_6d857448e539ef78c852c454ac3a6725 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_67be5b3f50695792a70daa316f00c8eb.setIcon(icon_6d857448e539ef78c852c454ac3a6725);
#
#
#         var popup_ef04a273196aca8af6173b4805a9980e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd1895f5b8d3f36afb4264e256d0c4db = $(`&lt;div id=&quot;html_fd1895f5b8d3f36afb4264e256d0c4db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coffeeshop Rock-it&lt;/div&gt;`)[0];
#                 popup_ef04a273196aca8af6173b4805a9980e.setContent(html_fd1895f5b8d3f36afb4264e256d0c4db);
#
#
#
#         marker_67be5b3f50695792a70daa316f00c8eb.bindPopup(popup_ef04a273196aca8af6173b4805a9980e)
#         ;
#
#
#
#
#             var marker_db687dcd52603d65e7286dce54b295cb = L.marker(
#                 [52.3794724, 4.8806733],
#                 {}
#             ).addTo(feature_group_f307b2a623dd54b0757be207f6de160a);
#
#
#             var icon_c9d840b605cd1aef478b9b90dc21d7bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db687dcd52603d65e7286dce54b295cb.setIcon(icon_c9d840b605cd1aef478b9b90dc21d7bc);
#
#
#         var popup_6bb7b4fbec51d777e9177cad953181a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffdb2446f11d59164b9c3dbe60b0d27a = $(`&lt;div id=&quot;html_ffdb2446f11d59164b9c3dbe60b0d27a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moods coffee corner&lt;/div&gt;`)[0];
#                 popup_6bb7b4fbec51d777e9177cad953181a4.setContent(html_ffdb2446f11d59164b9c3dbe60b0d27a);
#
#
#
#         marker_db687dcd52603d65e7286dce54b295cb.bindPopup(popup_6bb7b4fbec51d777e9177cad953181a4)
#         ;
#
#
#
#
#             var marker_994f09d81c8c1bd52f7f705830974a1c = L.marker(
#                 [52.3742722, 4.8915479],
#                 {}
#             ).addTo(feature_group_f307b
